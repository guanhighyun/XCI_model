# %%
# Adapted from https://github.com/elstonlab/PhagocytosisRosetteModel/blob/main/WPGAP_FP_Check_EA_Results.ipynb by J. Cody Herron
import numpy as np
from scipy.integrate import odeint
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
folder = os.getcwd()
file_loc = folder

threshold_good_score = 50 # Threshold for fitness function to be considered as a successful round of parameter searching
path, dirs, files = os.walk(file_loc).__next__()
len_files = 501 # Total number of rounds of parameter searching

runs_df = pd.DataFrame(index = range(len_files), columns=['Score','a_act', 'd_act', 'K_n', 'n', 'a_x', 'd_x', 'm',
                                                          'K_S', 'K_a', 'k1', 'k2', 'k4', 'k3', 'XbsT', 'sT']) # Load optimized parameters
best_scores = []
best_inds = []
plt.figure(figsize=(5,3))
for i in range(len_files):
    logbook = pickle.load( open( folder + '/' + str(i) + ".pickled", "rb" ) )
    runs_df.iloc[i] = np.insert(logbook[1][-1],0,logbook[0][-1])
        
    best_scores.append(logbook[0][-1])
    best_inds.append(logbook[1][-1])
  
    run = np.array(logbook[0])
    score = logbook[0][-1]

# %%
good_df = runs_df[runs_df['Score'] < threshold_good_score].sort_values('Score')

# %%
good_df
# Out:
#          Score      a_act     d_act          K_n         n       a_x  \
# 3    16.239691   0.179848  0.362697     1.307348  6.295737  3.846481
# 236  17.637216   0.744847  0.251048     1.000059  9.839469  9.091577
# 370  18.176918   1.776925  8.623968     1.953543  6.338844  2.814366
# 290  18.320567  57.776063  1.357981     2.000112  8.263569  1.950294
# 255  18.558914   25.87469  3.359742     2.848831  8.074003  9.736316
# 85   19.512062  12.701604  0.550246     4.261195   9.99173  9.370875
# 401  20.173832    0.17786   0.03311     1.023912  2.650231  4.064776
# 392   20.17862  18.847551  4.822742     1.016362  9.305485  8.680927
# 475  20.458168   3.696197  0.036271     4.666028  1.076292  8.989162
# 307  20.999969   3.215996  1.984489     2.228717  2.354977  9.999228
# 95   21.488428   0.047244  0.035923  9890.974063  2.933406  7.901831
# 223  21.943462   11.78327  1.266441      1.06632  3.153098  6.386421
# 428  22.118041  19.973789  0.049844     1.025672   9.99943  9.845722
# 16   22.779639   0.280698  0.376325     4.595345  1.150432  4.681164
# 197  23.413492   2.254566  0.029591     1.000655  9.951358  2.215545
# 156  24.647769   1.487258    0.0231     1.178696  9.719721  1.977077
# 154  24.970586   0.376913  0.484541     2.660939  6.165912  6.385431
# 90   25.225711    97.6323  0.065142     3.276369  2.870111  3.412819
# 282  25.556423   0.240248  0.208065     1.004032  1.124639  8.379551
# 360  26.208555    99.8722  7.557301     1.264219  7.221527  6.204665
# 155  26.995851    0.00248  0.015254     1.524635   2.58871   9.43717
# 371  28.519469   0.310417  0.040217     1.579294  2.572028  4.071263
# 490  28.991726   0.021834   0.00656     4.489275  1.013608  9.743346
    dy = [
        a_act/(1 +(s1b/K_n)**n) - d_act*act,
        a_x*act/(K_a + act) - d_x*x1f - k1*(XbsT - x1b)*x1f + k2*x1b/(1+(s1b/K_S)**m),
        k1*(XbsT - x1b)*x1f - k2*x1b/(1+(s1b/K_S)**m),
        k5*(sT - s1b)*(N_S*x1b - s1b)  - k4*s1b
        ]
    return dy

# %%
def DE2(y,t,arr_parameters_IP):
    act, x1f, x1b, s1b, x2f, x2b, s2b = y
    a_act, d_act, K_n, n, a_x, d_x, m, K_S, K_a, k1, k2, k4, k5, XbsT, sT = arr_parameters_IP
    N_S = round(sT/XbsT)
    dy = [
        a_act/(1 +(s1b/K_n)**n) + a_act/(1 +(s2b/K_n)**n) - d_act*act,
        a_x*act/(K_a + act) - d_x*x1f - k1*(XbsT - x1b)*x1f + k2*x1b/(1+(s1b/K_S)**m),
        k1*(XbsT - x1b)*x1f - k2*x1b/(1+(s1b/K_S)**m),
        k5*(sT - s1b - s2b)*(N_S*x1b - s1b)  - k4*s1b,
        a_x*act/(K_a + act) - d_x*x2f - k1*(XbsT - x2b)*x2f + k2*x2b/(1+(s2b/K_S)**m),
        k1*(XbsT - x2b)*x2f - k2*x2b/(1+(s2b/K_S)**m),
        k5*(sT - s1b - s2b)*(N_S*x2b - s2b)  - k4*s2b,
        ]
    return dy

# %%
def DE3(y,t,arr_parameters_IP):
    act, x1f, x1b, s1b, x2f, x2b, s2b, x3f, x3b, s3b = y
    a_act, d_act, K_n, n, a_x, d_x, m, K_S, K_a, k1, k2, k4, k5, XbsT, sT = arr_parameters_IP
    N_S = round(sT/XbsT)
    dy = [
        a_act/(1 +(s1b/K_n)**n) + a_act/(1 +(s2b/K_n)**n) + a_act/(1 +(s3b/K_n)**n) - d_act*act,
        a_x*act/(K_a + act) - d_x*x1f - k1*(XbsT - x1b)*x1f + k2*x1b/(1+(s1b/K_S)**m),
        k1*(XbsT - x1b)*x1f - k2*x1b/(1+(s1b/K_S)**m),
        k5*(sT - s1b - s2b - s3b)*(N_S*x1b - s1b)  - k4*s1b,
        a_x*act/(K_a + act) - d_x*x2f - k1*(XbsT - x2b)*x2f + k2*x2b/(1+(s2b/K_S)**m),
        k1*(XbsT - x2b)*x2f - k2*x2b/(1+(s2b/K_S)**m),
        k5*(sT - s1b - s2b - s3b)*(N_S*x2b - s2b)  - k4*s2b,
        a_x*act/(K_a + act) - d_x*x3f - k1*(XbsT - x3b)*x3f + k2*x3b/(1+(s3b/K_S)**m),
        k1*(XbsT - x3b)*x3f - k2*x3b/(1+(s3b/K_S)**m),
        k5*(sT - s1b - s2b - s3b)*(N_S*x3b - s3b)  - k4*s3b
        ]
    return dy
